# %% [markdown]
# **Use the knn implementation from scikit learn to classify the Iris dataset. Also show how performance of the model varies with different values of k.**

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
iris = load_iris()
X = iris.data
y = iris.target
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=75)
k_values = [5, 8, 9, 15, 26, 45, 78, 95]
score=[]
for k in k_values:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train, y_train)

    y_pred = knn.predict(X_test)

    accuracy = accuracy_score(y_test, y_pred)
    score.append(accuracy)
    print(f"Accuracy for k = {k}: {accuracy:.2f}")
# Out:
# Accuracy for k = 5: 1.00
# Accuracy for k = 8: 1.00
# Accuracy for k = 9: 1.00
# Accuracy for k = 15: 1.00
# Accuracy for k = 26: 0.97
# Accuracy for k = 45: 0.93
# Accuracy for k = 78: 0.83
# Accuracy for k = 95: 0.67

# %%
import matplotlib.pyplot as plt
plt.plot(k_values, score)
plt.title("K value v/s Accuracy")
plt.xlabel('Value of K for KNN')
plt.ylabel('testing Accuracy')
# Out:
# Text(0, 0.5, 'testing Accuracy')

# %% [markdown]
# Write your own implementation for knn with 4 different distance metrics and check on Iris dataset.

# %%
import numpy as np
def distance(x1, x2):
    return np.sqrt(np.sum(np.square(x1 - x2)))

def predict(X_train, y_train, x_test, k):
    distances = []

    for i in range(len(X_train)):
        distances.append((distance

    (x_test, X_train[i]), i))

    distances.sort()

    targets = [y_train[distances[i][1]] for i in range(k)]

    return max(set(targets), key=targets.count)

def k_nearest_neighbor(X_train, y_train, X_test, k):
    predictions = []

    for i in range(len(X_test)):
        predictions.append(predict(X_train, y_train, X_test[i], k))

    return np.asarray(predictions)
k_values = [5, 8, 9, 15, 26, 45, 78, 95]
score=[]
for k in k_values:
    predictions = k_nearest_neighbor(X_train, y_train, X_test, k)
    accuracy = accuracy_score(y_test, predictions)
    score.append(accuracy)
    print(f"Accuracy for k = {k}: {accuracy:.2f}")
import matplotlib.pyplot as plt
plt.plot(k_values, score)
plt.title("K value v/s Accuracy")
plt.xlabel('Value of K for KNN')
plt.ylabel('testing Accuracy')
# Out:
# Accuracy for k = 5: 1.00
# Accuracy for k = 8: 1.00
# Accuracy for k = 9: 1.00
# Accuracy for k = 15: 1.00
# Accuracy for k = 26: 0.97
# Accuracy for k = 45: 0.93
# Accuracy for k = 78: 0.83
# Accuracy for k = 95: 0.67
# Text(0, 0.5, 'testing Accuracy')

# %% [markdown]
# Apply your own implementation of Knn to any instance of Pima Indians Diabetes Database from Kaggle or Github and submit notebooks for all 3 exercises.

# %%
import pandas as pd
df = pd.read_csv("/kaggle/input/pima-indians-diabetes-database/diabetes.csv")
X = df.iloc[:, :-1].values
y = df.iloc[:, -1].values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=75)
k_values = [5, 8, 9, 15, 26, 45, 78, 95]
for k in k_values:
    predictions = k_nearest_neighbor(X_train, y_train, X_test, k)
    accuracy = accuracy_score(y_test, predictions)
    score.append(accuracy)
    print(f"Accuracy for k = {k}: {accuracy:.2f}")
# Out:
# Accuracy for k = 5: 0.73
# Accuracy for k = 8: 0.73
# Accuracy for k = 9: 0.73
# Accuracy for k = 15: 0.75
# Accuracy for k = 26: 0.73
# Accuracy for k = 45: 0.72
# Accuracy for k = 78: 0.73
# Accuracy for k = 95: 0.71
